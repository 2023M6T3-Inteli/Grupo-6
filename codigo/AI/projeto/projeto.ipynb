# %%
import opendatasets as od
import matplotlib as plt
import pandas as pd

# %%
od.download(
    "https://www.kaggle.com/datasets/shubhammehta21/movie-lens-small-latest-dataset")
# Out:
# Skipping, found downloaded files in ".\movie-lens-small-latest-dataset" (use force=True to force download)

# %%
file = pd.read_csv("movie-lens-small-latest-dataset/ratings.csv")

# %%
file2 = pd.read_csv("movie-lens-small-latest-dataset/movies.csv")

# %%
file.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
file = file.drop(columns=['timestamp'])

# %%
group = file.groupby('movieId')

# %%
file2.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df1 = pd.DataFrame(file)
df2 = pd.DataFrame(file2)
merged_df = pd.merge(df1, df2, on='movieId')
merged_df = merged_df.drop_duplicates()
print(merged_df)
merged_df.to_excel("merged_df.xlsx", index=False)
# Out:
#         userId  movieId  rating                             title  \
# 0            1        1     4.0                  Toy Story (1995)
# 1            5        1     4.0                  Toy Story (1995)
# 2            7        1     4.5                  Toy Story (1995)
# 3           15        1     2.5                  Toy Story (1995)
# 4           17        1     4.5                  Toy Story (1995)
# ...        ...      ...     ...                               ...
# 100831     610   160341     2.5                  Bloodmoon (1997)
# 100832     610   160527     4.5  Sympathy for the Underdog (1971)
# 100833     610   160836     3.0                     Hazard (2005)
# 100834     610   163937     3.5                Blair Witch (2016)
# 100835     610   163981     3.5                         31 (2016)
#
#                                              genres
# 0       Adventure|Animation|Children|Comedy|Fantasy
# 1       Adventure|Animation|Children|Comedy|Fantasy
# ...

# %%
valores_unicos = merged_df["genres"].unique().tolist()
print(valores_unicos)
print(len(valores_unicos))
# Out:
# ['Adventure|Animation|Children|Comedy|Fantasy', 'Comedy|Romance', 'Action|Crime|Thriller', 'Mystery|Thriller', 'Crime|Mystery|Thriller', 'Action|Comedy|Horror|Thriller', 'Adventure|Comedy|Crime|Romance', 'Action|Drama|War', 'Action|Drama|Romance|War', 'Comedy|War', 'Action|Romance|Western', 'Comedy', 'Adventure|Comedy', 'Comedy|Drama', 'Action|Adventure|Sci-Fi', 'Comedy|Crime|Drama|Thriller', 'Action|Crime|Drama|Thriller', 'Comedy|Drama|Romance|War', 'Adventure|Children|Romance', 'Action|Comedy|Crime|Fantasy', 'Action|Thriller', 'Thriller', 'Action|Adventure|Sci-Fi|Thriller', 'Drama|War', 'Comedy|Romance|Thriller', 'Action|Adventure|Comedy|Romance', 'Action|Drama|Western', 'Adventure|Drama|Western', 'Crime|Horror|Thriller', 'Animation|Children|Fantasy|Musical', 'Action|Adventure|Mystery|Thriller', 'Adventure|Animation|Children|Fantasy|Musical', 'Adventure|Animation|Children|Comedy|Fantasy|Sci-Fi', 'Action|Adventure|Thriller', 'Action|Adventure|Romance|Thriller', 'Adventure|Children|F
# ...

# %%
filmes_comedia = [valores_unicos for valores_unicos in valores_unicos if 'comedy' in valores_unicos.lower()]

print(filmes_comedia)
print(len(filmes_comedia))
# Out:
# ['Adventure|Animation|Children|Comedy|Fantasy', 'Comedy|Romance', 'Action|Comedy|Horror|Thriller', 'Adventure|Comedy|Crime|Romance', 'Comedy|War', 'Comedy', 'Adventure|Comedy', 'Comedy|Drama', 'Comedy|Crime|Drama|Thriller', 'Comedy|Drama|Romance|War', 'Action|Comedy|Crime|Fantasy', 'Comedy|Romance|Thriller', 'Action|Adventure|Comedy|Romance', 'Adventure|Animation|Children|Comedy|Fantasy|Sci-Fi', 'Children|Comedy|Fantasy|Musical', 'Adventure|Comedy|Fantasy', 'Action|Adventure|Comedy|Fantasy|Romance', 'Action|Comedy|Musical', 'Comedy|Musical|War', 'Comedy|Fantasy|Romance', 'Adventure|Comedy|Sci-Fi', 'Comedy|Fantasy', 'Action|Comedy|Crime|Drama|Sci-Fi', 'Action|Comedy|Crime|Drama', 'Comedy|Crime|Romance', 'Action|Adventure|Comedy', 'Action|Comedy|Sci-Fi', 'Comedy|Crime', 'Action|Adventure|Children|Comedy|Fantasy', 'Adventure|Comedy|Sci-Fi|Western', 'Adventure|Children|Comedy|Fantasy|Sci-Fi', 'Animation|Children|Comedy|Musical', 'Adventure|Animation|Children|Comedy', 'Action|Comedy|Crime
# ...

# %%
contador = 0
contador2 = len(filmes_comedia)
df_comedia = pd.DataFrame()

for i in range(contador, contador2):
    df_comedia = df_comedia.append(
        merged_df[merged_df['genres'] == filmes_comedia[contador]])
    contador += 1

print(df_comedia)
df_comedia.to_excel("merged_df.xlsx", index=False)
# Out:
# C:\Users\janfr\AppData\Local\Temp\ipykernel_40508\2810936725.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comedia = df_comedia.append(
# C:\Users\janfr\AppData\Local\Temp\ipykernel_40508\2810936725.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comedia = df_comedia.append(
# C:\Users\janfr\AppData\Local\Temp\ipykernel_40508\2810936725.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comedia = df_comedia.append(
# C:\Users\janfr\AppData\Local\Temp\ipykernel_40508\2810936725.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comedia = df_comedia.append(
# ...

# %%
filmes_unicos = df_comedia["title"].unique().tolist()
print(filmes_unicos)
print(len(filmes_unicos))
# Out:
# ['Toy Story (1995)', 'Toy Story 2 (1999)', 'Monsters, Inc. (2001)', 'Antz (1998)', 'Adventures of Rocky and Bullwinkle, The (2000)', "Emperor's New Groove, The (2000)", 'Shrek the Third (2007)', 'The Good Dinosaur (2015)', 'Asterix and the Vikings (Astérix et les Vikings) (2006)', 'Tale of Despereaux, The (2008)', 'Moana (2016)', 'Wild, The (2006)', 'Turbo (2013)', 'Grumpier Old Men (1995)', "She's the One (1996)", 'Wedding Singer, The (1998)', '20 Dates (1998)', "You've Got Mail (1998)", 'Four Weddings and a Funeral (1994)', 'Barcelona (1994)', 'Truth About Cats & Dogs, The (1996)', 'Love in the Afternoon (1957)', 'Strictly Ballroom (1992)', "There's Something About Mary (1998)", 'Black Cat, White Cat (Crna macka, beli macor) (1998)', 'Clueless (1995)', 'Pretty Woman (1990)', 'Sabrina (1995)', 'Mallrats (1995)', 'Nine Months (1995)', 'Forget Paris (1995)', 'I.Q. (1994)', 'Milk Money (1994)', 'Only You (1994)', 'While You Were Sleeping (1995)', 'Speechless (1994)', 'Dave (1993)', 'En
# ...
